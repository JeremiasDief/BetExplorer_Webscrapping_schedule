# %%
import pandas as pd

# %%
df_links = pd.read_excel("./Next_Matches/Matches_2023-02-27.xlsx", header=None, usecols="P")
df_links
# Out:
#                                                    15
# 0   /soccer/argentina/liga-profesional/barracas-ce...
# 1   /soccer/argentina/liga-profesional/racing-club...
# 2   /soccer/argentina/liga-profesional/central-cor...
# 3   /soccer/argentina/primera-nacional/agropecuari...
# 4   /soccer/azerbaijan/premier-league/qarabag-agda...
# 5   /soccer/bolivia/division-profesional/jorge-wil...
# 6   /soccer/bulgaria/parva-liga/pirin-blagoevgrad-...
# 7   /soccer/chile/primera-division/copiapo-o-higgi...
# 8   /soccer/chile/primera-division/everton-a-itali...
# 9   /soccer/chile/primera-b/club-deportes-santa-cr...
# 10  /soccer/chile/primera-b/cobreloa-barnechea/CCR...
# 11  /soccer/colombia/primera-a/atl-nacional-huila/...
# 12  /soccer/colombia/primera-a/chico-dep-pasto/l4y...
# 13  /soccer/colombia/primera-b/atletico-f-c-leones...
# 14  /soccer/colombia/primera-b/barranquilla-cucuta...
# 15  /soccer/costa-rica/primera-division/zeledon-he...
# ...

# %%
df_links.iloc[34]
# Out:
# 15    /soccer/mexico/liga-mx/club-tijuana-pachuca/t8...
# Name: 34, dtype: object

# %%
"/soccer/netherlands/eerste-divisie/jong-psv-jong-az-alkmaar/GlYPD98O/" in df_links.values
# Out:
# True
